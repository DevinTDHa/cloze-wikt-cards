# %% [markdown]
# # Extraction

# %%
import json
import pandas as pd
from typing import List


def load_wiktextract(file_path: str) -> pd.DataFrame:
    """Loads JSONL file with wiktextract data (See: https://github.com/tatuylonen/wiktextract)"""

    with open(file_path) as f:
        lines = f.read().splitlines()

    line_dicts: List[dict] = [json.loads(line) for line in lines]
    df: pd.DataFrame = pd.DataFrame(line_dicts)

    return df.fillna("")

# %%
dump_path = "/media/ducha/SSDSHARED/VN/wikt/kaikki.org-dictionary-Vietnamese.jsonl"
wikt_df = load_wiktextract(dump_path)

# %%
wikt_df.columns
# Out:
# Index(['pos', 'forms', 'word', 'lang', 'lang_code', 'senses', 'head_templates',
#        'sounds', 'etymology_text', 'etymology_templates', 'etymology_number',
#        'derived', 'wikipedia', 'related', 'synonyms', 'categories', 'antonyms',
#        'descendants', 'coordinate_terms', 'meronyms', 'hypernyms'],
#       dtype='object')

# %%
example = "với"

# %%
# Find all entries that contain the word "hàng"
ex_entries = wikt_df[wikt_df["word"] == example]

# %%
ex_entries
# Out:
#            pos                                              forms word  \
# 7064      verb                   [{'form': '𢭲', 'tags': ['CJK']}]  với
# 7065      noun                   [{'form': '𢭲', 'tags': ['CJK']}]  với
# 7066      prep  [{'form': '众', 'tags': ['CJK']}, {'form': '喟',...  với
# 7067  particle                                                     với
#
#             lang lang_code                                             senses  \
# 7064  Vietnamese        vi  [{'links': [['reach', 'reach']], 'glosses': ['...
# 7065  Vietnamese        vi  [{'links': [['stretch', 'stretch'], ['hand', '...
# 7066  Vietnamese        vi  [{'examples': [{'text': 'cộng 2 với 3', 'engli...
# 7067  Vietnamese        vi  [{'examples': [{'text': 'Cho con đi với.', 'en...
#
#                                          head_templates  \
# 7064  [{'name': 'head', 'args': {'1': 'vi', '2': 've...
# 7065  [{'name': 'head', 'args': {'1': 'vi', '2': 'no...
# 7066  [{'name': 'head', 'args': {'1': 'vi', '2': 'pr...
# 7067  [{'name': 'head', 'args': {'1': 'vi', '2': 'pa...
#
#                                                  sounds  \
# 7064  [{'ipa': '[vəːj˧˦]', 'tags': ['Hà-Nội']}, {'ip...
# 7065  [{'ipa': '[vəːj˧˦]', 'tags': ['Hà-Nội']}, {'ip...
# 7066  [{'ipa': '[vəːj˧˦]', 'tags': ['Hà-Nội']}, {'ip...
# 7067  [{'ipa': '[vəːj˧˦]', 'tags': ['Hà-Nội']}, {'ip...
#
#                                          etymology_text  \
# 7064
# 7065
# 7066  Cognate with Muong Bi pỡi.\nProbably related a...
# 7067  Cognate with Muong Bi pỡi.\nProbably related a...
#
#                                     etymology_templates  ... derived  \
# 7064                                                     ...
# 7065                                                     ...
# 7066  [{'name': 'cog', 'args': {'1': 'mtq', '2': '-'...  ...
# 7067  [{'name': 'cog', 'args': {'1': 'mtq', '2': '-'...  ...
#
#      wikipedia                                            related  \
# 7064
# 7065
# 7066            [{'english': '(to subtract) from', 'word': 'đi...
# 7067
#
#                                                synonyms categories antonyms  \
# 7064
# 7065
# 7066  [{'tags': ['obsolete'], 'word': 'vuối', '_dis1...
# 7067  [{'tags': ['obsolete'], 'word': 'vuối', '_dis1...
#
#      descendants coordinate_terms meronyms hypernyms
# 7064
# 7065
# 7066
# 7067
#
# [4 rows x 21 columns]

# %%
from typing import List
import pandas as pd


def get_entries(wikt_df: pd.DataFrame, word: str) -> pd.DataFrame:
    return wikt_df[wikt_df["word"] == word]

# %% [markdown]
# ## Abstecher: glosses and raw_glosses analysis

# %%
glosses_lens = []
raw_glosses_lens = []
for i, row in wikt_df.iterrows():
    senses = row.get("senses", [])
    for senses in senses:
        if "glosses" in senses:
            glosses_lens.append((i, len(senses["glosses"])))
        if "raw_glosses" in senses:
            raw_glosses_lens.append((i, len(senses["raw_glosses"])))
max(glosses_lens, key=lambda x: x[1]), max(raw_glosses_lens, key=lambda x: x[1])

# %%
wikt_df.iloc[7066]["senses"]
# Out:
# [{'examples': [{'text': 'cộng 2 với 3',
#     'english': 'to add 2 to 3',
#     'type': 'example'},
#    {'text': 'nhân tổng với hiệu',
#     'english': 'to multiply this sum by this difference',
#     'type': 'example'}],
#   'links': [['with', 'with'],
#    ['together with', 'together with'],
#    ['along with', 'along with'],
#    ['and', 'and'],
#    ['arithmetic', 'arithmetic'],
#    ['cộng', 'cộng#Vietnamese'],
#    ['add', 'add#English'],
#    ['nhân', 'nhân#Vietnamese'],
#    ['multiply', 'multiply#English'],
#    ['to', 'to#English'],
#    ['by', 'by#English']],
#   'raw_glosses': ['with; together with; along with; and',
#    '(arithmetic, after cộng (“to add”) or nhân (“to multiply”)) to or by'],
#   'glosses': ['with; together with; along with; and',
#    '(arithmetic, after cộng (“to add”) or nhân (“to multiply”)) to or by',
#    'to or by'],
#   'topics': ['arithmetic'],
#   'raw_tags': ['after cộng (“to add”) or nhân (“to multiply”)'],
#   'id': 'en-với-vi-prep-~f1SuIAl',
#   'categories': [{'name': 'Arithmetic',
#     'kind': 'topical',
#     'parents': ['Applied sciences',
#      'Mathematics',
#      'Sciences',
#      'Formal sciences',
#      'All topics',
#      'Fundamental'],
#     'source': 'w',
#     'orig': 'vi:Arithmetic',
#     'langcode': 'vi'},
#    {'name': 'Vietnamese entries with incorrect language header',
#     'kind': 'other',
#     'parents': ['Entries with incorrect language header', 'Entry maintenance'],
#     'source': 'w+disamb',
#     '_dis': '3 24 22 23 22 7 0'},
#    {'name': 'Vietnamese particles',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '1 24 22 22 24 6 0'},
#    {'name': 'Vietnamese prepositions',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '10 10 19 23 17 21 0'}]},
#  {'examples': [{'text': 'góc ABC kề với góc CBD',
#     'english': 'angle ABC is adjacent to angle CBD',
#     'type': 'example'},
#    {'text': 'đường thẳng d song song/vuông góc với đường thẳng e/mặt phẳng p',
#     'english': 'line d is parallel/perpendicular to line e/plane p',
#     'type': 'example'}],
#   'links': [['with', 'with'],
#    ['together with', 'together with'],
#    ['along with', 'along with'],
#    ['and', 'and'],
#    ['geometry', 'geometry'],
#    ['kề', 'kề#Vietnamese'],
#    ['adjacent', 'adjacent'],
#    ['bù', 'bù#Vietnamese'],
#    ['supplementary', 'supplementary'],
#    ['song song', 'song song#Vietnamese'],
#    ['parallel', 'parallel'],
#    ['vuông góc', 'vuông góc#Vietnamese'],
#    ['perpendicular', 'perpendicular'],
#    ['to', 'to']],
#   'raw_glosses': ['with; together with; along with; and',
#    '(geometry, after kề (“adjacent”), bù (“supplementary”), song song (“parallel”), vuông góc (“perpendicular”), etc.) to'],
#   'glosses': ['with; together with; along with; and',
#    '(geometry, after kề (“adjacent”), bù (“supplementary”), song song (“parallel”), vuông góc (“perpendicular”), etc.) to',
#    'to'],
#   'topics': ['geometry', 'mathematics', 'sciences'],
#   'qualifier': 'song song (“parallel”)',
#   'tags': ['usually'],
#   'raw_tags': ['after kề (“adjacent”)'],
#   'id': 'en-với-vi-prep-394FbZ~m',
#   'categories': [{'name': 'Geometry',
#     'kind': 'topical',
#     'parents': ['Mathematics',
#      'Formal sciences',
#      'Sciences',
#      'All topics',
#      'Fundamental'],
#     'source': 'w',
#     'orig': 'vi:Geometry',
#     'langcode': 'vi'},
#    {'name': 'Vietnamese entries with incorrect language header',
#     'kind': 'other',
#     'parents': ['Entries with incorrect language header', 'Entry maintenance'],
#     'source': 'w+disamb',
#     '_dis': '3 24 22 23 22 7 0'},
#    {'name': 'Vietnamese particles',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '1 24 22 22 24 6 0'},
#    {'name': 'Vietnamese prepositions',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '10 10 19 23 17 21 0'}]},
#  {'examples': [{'text': '(Đối) với tôi, vấn đề này chẳng có gì đáng lo ngại cả.',
#     'english': "To me, there's nothing to worry about this problem.",
#     'type': 'example'}],
#   'links': [['đối với', 'đối với#Vietnamese'], ['to', 'to']],
#   'glosses': ['Short for đối với (“to”).'],
#   'tags': ['abbreviation', 'alt-of'],
#   'alt_of': [{'word': 'đối với', 'extra': 'to'}],
#   'id': 'en-với-vi-prep-U~wIry0k',
#   'categories': [{'name': 'Vietnamese entries with incorrect language header',
#     'kind': 'other',
#     'parents': ['Entries with incorrect language header', 'Entry maintenance'],
#     'source': 'w+disamb',
#     '_dis': '3 24 22 23 22 7 0'},
#    {'name': 'Vietnamese particles',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '1 24 22 22 24 6 0'},
#    {'name': 'Vietnamese prepositions',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '10 10 19 23 17 21 0'}]},
#  {'examples': [{'text': 'Dẹp cha nó ba cái vụ Vũng Tàu với vũng ghe đi! Bộ thằng Hai Hùng để tao mặc quần đùi bộ đội xuống biển, xuống đến đâu sủi bong bóng ra đến đó hả. Dẹp! Cùng đi, cùng vô, cùng về.',
#     'ref': '1995, Chu Lai, Đi tìm dĩ vãng [Seeking the Past], Nhà xuất bản Hội Nhà văn',
#     'type': 'quotation',
#     'roman': 'To hell with all that Vũng Tàu shit! Does Hai Hùng really expect me to dive into the ocean in trunks and froth all over my mouth? Fuck that! We go in and go out, together!'}],
#   'links': [['với chẳng', 'với chẳng#Vietnamese']],
#   'glosses': ['Ellipsis of với chẳng.'],
#   'tags': ['abbreviation', 'alt-of', 'ellipsis'],
#   'alt_of': [{'word': 'với chẳng'}],
#   'id': 'en-với-vi-prep-yqOq93~0',
#   'categories': [{'name': 'Vietnamese ellipses',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w'},
#    {'name': 'Vietnamese prepositions',
#     'kind': 'other',
#     'parents': [],
#     'source': 'w+disamb',
#     '_dis': '10 10 19 23 17 21 0'}]}]

# %%
[
    e["raw_glosses"] if "raw_glosses" in e else e["glosses"]
    for e in wikt_df.iloc[7066]["senses"]
]
# Out:
# [['with; together with; along with; and',
#   '(arithmetic, after cộng (“to add”) or nhân (“to multiply”)) to or by'],
#  ['with; together with; along with; and',
#   '(geometry, after kề (“adjacent”), bù (“supplementary”), song song (“parallel”), vuông góc (“perpendicular”), etc.) to'],
#  ['Short for đối với (“to”).'],
#  ['Ellipsis of với chẳng.']]

# %% [markdown]
# # Formatting
#
# Notes:
#
# - each `"sense"` stands for a meaning of the word (of this pos) they are dicts:
#   - [ ] `glosses` are the quick translations
#     - each meaning-pos combination might have multiple meanings
#   - [ ] sometimes `raw_glosses` are available with a more detailed explanation
#   - [ ] also use `examples` if available
#   - [ ] also use `synonyms` if available

# %%
ex_entries.iloc[0]
# Out:
# pos                                                                 verb
# forms                                   [{'form': '𢭲', 'tags': ['CJK']}]
# word                                                                 với
# lang                                                          Vietnamese
# lang_code                                                             vi
# senses                 [{'links': [['reach', 'reach']], 'glosses': ['...
# head_templates         [{'name': 'head', 'args': {'1': 'vi', '2': 've...
# sounds                 [{'ipa': '[vəːj˧˦]', 'tags': ['Hà-Nội']}, {'ip...
# etymology_text
# etymology_templates
# etymology_number                                                     1.0
# derived
# wikipedia
# related
# synonyms
# categories
# antonyms
# descendants
# coordinate_terms
# meronyms
# hypernyms
# Name: 7064, dtype: object

# %%
ex_senses = ex_entries.iloc[2]["senses"]
ex_senses[0]
# Out:
# {'examples': [{'text': 'cộng 2 với 3',
#    'english': 'to add 2 to 3',
#    'type': 'example'},
#   {'text': 'nhân tổng với hiệu',
#    'english': 'to multiply this sum by this difference',
#    'type': 'example'}],
#  'links': [['with', 'with'],
#   ['together with', 'together with'],
#   ['along with', 'along with'],
#   ['and', 'and'],
#   ['arithmetic', 'arithmetic'],
#   ['cộng', 'cộng#Vietnamese'],
#   ['add', 'add#English'],
#   ['nhân', 'nhân#Vietnamese'],
#   ['multiply', 'multiply#English'],
#   ['to', 'to#English'],
#   ['by', 'by#English']],
#  'raw_glosses': ['with; together with; along with; and',
#   '(arithmetic, after cộng (“to add”) or nhân (“to multiply”)) to or by'],
#  'glosses': ['with; together with; along with; and',
#   '(arithmetic, after cộng (“to add”) or nhân (“to multiply”)) to or by',
#   'to or by'],
#  'topics': ['arithmetic'],
#  'raw_tags': ['after cộng (“to add”) or nhân (“to multiply”)'],
#  'id': 'en-với-vi-prep-~f1SuIAl',
#  'categories': [{'name': 'Arithmetic',
#    'kind': 'topical',
#    'parents': ['Applied sciences',
#     'Mathematics',
#     'Sciences',
#     'Formal sciences',
#     'All topics',
#     'Fundamental'],
#    'source': 'w',
#    'orig': 'vi:Arithmetic',
#    'langcode': 'vi'},
#   {'name': 'Vietnamese entries with incorrect language header',
#    'kind': 'other',
#    'parents': ['Entries with incorrect language header', 'Entry maintenance'],
#    'source': 'w+disamb',
#    '_dis': '3 24 22 23 22 7 0'},
#   {'name': 'Vietnamese particles',
#    'kind': 'other',
#    'parents': [],
#    'source': 'w+disamb',
#    '_dis': '1 24 22 22 24 6 0'},
#   {'name': 'Vietnamese prepositions',
#    'kind': 'other',
#    'parents': [],
#    'source': 'w+disamb',
#    '_dis': '10 10 19 23 17 21 0'}]}

# %%
def process_senses(senses):
    senses_processed = []

    for sense in senses:
        if "glosses" not in sense and "raw_glosses" not in sense:
            continue

        meaning = (
            sense["raw_glosses"][0] if "raw_glosses" in sense else sense["glosses"][0]
        )  # Always take the first, main meaning

        # Check if the meaning is already in the list
        sense_dict = next(
            (s for s in senses_processed if s["meaning"] == meaning),
            {"meaning": meaning},
        )
        # if the only key was "meaning"
        created_new = len(sense_dict) == 1

        if "examples" in sense:
            examples = sense_dict.get("examples", [])
            for ex in sense["examples"]:
                if "english" not in ex:
                    examples.append(ex["text"])
                else:
                    examples.append(ex["text"] + " ― " + ex["english"])
            sense_dict["examples"] = examples
        if created_new:  # Only append if a new sense dict was created
            senses_processed.append(sense_dict)

    meanings_formatted = [sense["meaning"] for sense in senses_processed]
    senses_str = "; ".join(meanings_formatted)
    return senses_processed, senses_str


def json_dump_entries(entries: pd.DataFrame) -> tuple[str, str]:
    out_entries = []
    entries_short_str = []
    for _, row in entries.iterrows():
        cur_entry = {}
        cur_entry["pos"] = row["pos"]
        if "synonyms" in row and row["synonyms"]:  # Synonyms can be NaN
            cur_entry["synonyms"] = [syn["word"] for syn in row["synonyms"]]
        cur_entry["meanings"], senses_string = process_senses(row["senses"])
        if not cur_entry["meanings"]:
            continue
        out_entries.append(cur_entry)

        entries_short_str.append(f"{row['pos']}: {senses_string}")

    short_meanings = " | ".join(entries_short_str)

    return json.dumps(out_entries), short_meanings

# %%
json_str, short_str = json_dump_entries(ex_entries)
with open("example.json", "w") as f:
    f.write(json_str)
