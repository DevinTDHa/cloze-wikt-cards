# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/home/ducha/Dropbox/Projects/viet-examples/current_anki_vn.txt",
    sep="\t",
    header=None,
    comment="#",
)

# %%
escaped = df[3].str.contains('\\\\"').fillna(False)
# Out:
# /tmp/ipykernel_40905/237179873.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   escaped = df[3].str.contains('\\\\"').fillna(False)

# %%
df[escaped]
# Out:
#                0                  1  \
# 10    y+:G1%~![]                khử
# 24    Kxg&9+U=K^                teo
# 47    Q/H>@UIk^t          bình thản
# 56    jZm&E^3Y~T                sau
# 60    n8YE<(K;*c          giọng nói
# ...          ...                ...
# 1097  uD9zM45udU  quyển tiểu thuyết
# 1099  vtAr`cna2O          thành lập
# 1103  rig@o}3aqL               ấp ủ
# 1144  I9roJ_[c|T       khinh thường
# 1204  E5mZD2Vb75              mount
#
#                                                       2  \
# 10                           noun: to remove, to rid of
# 24                          verb: to shrink, to shrivel
# 47    adj: indifferently calm; imperturbable; quiet;...
# 56    adj: rear, hind, back; next, subsequent | adv:...
# 60                                          noun: voice
# ...                                                 ...
# 1097                                              novel
# 1099            verb: to establish; to set up; to found
# ...

# %%
df[3] = df[3].str.replace("\\", "").replace('""', '"')

# %%
df[escaped]
# Out:
#                0                  1  \
# 10    y+:G1%~![]                khử
# 24    Kxg&9+U=K^                teo
# 47    Q/H>@UIk^t          bình thản
# 56    jZm&E^3Y~T                sau
# 60    n8YE<(K;*c          giọng nói
# ...          ...                ...
# 1097  uD9zM45udU  quyển tiểu thuyết
# 1099  vtAr`cna2O          thành lập
# 1103  rig@o}3aqL               ấp ủ
# 1144  I9roJ_[c|T       khinh thường
# 1204  E5mZD2Vb75              mount
#
#                                                       2  \
# 10                           noun: to remove, to rid of
# 24                          verb: to shrink, to shrivel
# 47    adj: indifferently calm; imperturbable; quiet;...
# 56    adj: rear, hind, back; next, subsequent | adv:...
# 60                                          noun: voice
# ...                                                 ...
# 1097                                              novel
# 1099            verb: to establish; to set up; to found
# ...

# %%
df.to_csv(
    "/home/ducha/Dropbox/Projects/viet-examples/current_anki_vn_clean.txt",
    sep="\t",
    header=None,
    index=False,
    quotechar="\"",
    escapechar="",
    quoting=3,
)
